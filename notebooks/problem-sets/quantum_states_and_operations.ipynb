# %% [markdown]
# ## Problem 1
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-1") -->
#
# <!-- ::: .question -->
#
# Which one is **not** a valid quantum state?
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. $\begin{pmatrix} 1 \\\\ 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 2. $\frac{1}{\sqrt{2}} \begin{pmatrix} 1 \\\\ 1 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 3. $\frac{1}{3} \begin{pmatrix} 2 \\\\ 1 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 2
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-2") -->
#
# <!-- ::: .question -->
#
# Which one is a valid quantum **gate**?
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 1. $\begin{pmatrix} 0 & 1\\\\ 1 & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 2. $\begin{pmatrix} 0 & 0\\\\ 1 & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $\begin{pmatrix} 0 & 1\\\\ 0 & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 3
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-3") -->
# <!-- ::: .question -->
#
# Which one is a valid the complex conjugate of the following operator?
#
# $\hat{S} = \begin{pmatrix} 1 & 0\\\\ 0 & i \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. $\hat{S}^\dagger = \begin{pmatrix} 1 & 0\\\\ 0 & i \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 2. $\hat{S}^\dagger = \begin{pmatrix} 1 & 0\\\\ 0 & -i \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $\hat{S}^\dagger = \begin{pmatrix} 1 & 0\\\\ 0 & 1 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 4
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# Which of the following operator is Hermitian?
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. $\hat{S} = \begin{pmatrix} 1 & 0\\\\ 0 & i \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 2. $\hat{T} = \begin{pmatrix} 1 & 0\\\\ 0 & e^{i \pi/4} \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 3. $\hat{Z} = \begin{pmatrix} 1 & 0\\\\ 0 & -1 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 5
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# What's the value of the overlap between the following two states $\langle 0 | + \rangle$?
#
# $| + \rangle = \frac{1}{\sqrt{2}} \begin{pmatrix} 1 \\\\ 1 \end{pmatrix}$
#
# $| 0 \rangle = \begin{pmatrix} 1 \\\\ 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. 0
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 2. $1/\sqrt{2}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. 1
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 6
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# What's the result of applying Pauli-Z operator to the $|0\rangle$?
#
# $Z| 0 \rangle=$
#
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 1. $|0\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 2. $|1\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $-|1\rangle$
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $|+\rangle$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 7
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# What's the result of applying Pauli-Z operator to the $|1\rangle$?
#
# $Z| 1 \rangle=$
#
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. $|0\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 2. $|1\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 3. $-|1\rangle$
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $|+\rangle$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 8
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# What's the result of applying Pauli-X operator to the $|0\rangle$?
#
# $X| 0 \rangle=$
#
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. $|0\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 2. $|1\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $-|1\rangle$
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $|+\rangle$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 9
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# What's the result of applying Pauli-X operator to the $|1\rangle$?
#
# $X| 1 \rangle=$
#
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 1. $|0\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 2. $|1\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $-|1\rangle$
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $|+\rangle$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 10
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# What's the product of the following Pauli operators?
#
# $X.Y=$
#
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. $i X$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 2. $i Y$
#
# <!-- ::: -->
#
# <!-- ::: .option(x) -->
#
# 3. $i Z$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 11
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# What's the product of the following Pauli operators?
#
# $X.Z=$
#
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 1. $i X$
#
# <!-- ::: -->
#
# <!-- ::: .option (x) -->
#
# 2. $-i Y$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $i Z$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Problem 12
#
# <!-- ::: q-quiz(goal="quantum-states-and-operators-4") -->
# <!-- ::: .question -->
#
# What's the product of the following Pauli operators?
#
# $Y.Y=$
#
#
# <!-- ::: -->
#
# <!-- ::: .option (x) -->
#
# 1. $I$
#
# <!-- ::: -->
#
# <!-- ::: .option (x) -->
#
# 2. $Y$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 3. $-Y$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->
