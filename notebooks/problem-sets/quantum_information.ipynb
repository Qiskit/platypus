# %% [markdown]
# # Quantum information problem set

# %% [markdown]
# ## Overview
#
# ### What is the purpose of these problems?
#
# One of the most effective ways to learn is to engage actively with the content of interest. By working through some of these problems, you will have the opportunity to
#
# 1. hone your skills and knowledge, and
# 1. receive feedback so that you can make corrections to your understanding.
#
# ### What will you learn by doing these problems?
#
# Doing the exercises in the following sections will, over time and repetition, develop your expertise in the analysis of quantum systems, including transforming and measuring systems. The tools and techniques you learn here will underlie much of the field of quantum information.
#
# ### How to use these practice problems
#
# The problems generally increase in difficulty going further down, testing increasingly sophisticated skills. The section titles give an idea of what skill the problems intend to improve. If the problems in a given section are too easy for you, **don't hesitate to skip them** and take note that you have mastered the corresponding skill. If a problem is too challenging, try to figure out what makes the problem challenging and **go back to earlier problems** if necessary.
#
# When hints and answers are provided, try your best to **complete as much of the problem as you can first**, then look at the hints and answers when stuck or to check your work. Sometimes the answers will have further explanation and commentary, which may add perspective to the problem. Don't worry if you don't understand all of the explanation, or if you did the problem a different way. The hints and answers add interactivity to the problems and allow you to reflect on the material.
#
# ### What is the assumed background for these problems?
#
# The problems here complement the quantum information material discussed in the [Single Systems lesson](https://learn.qiskit.org/course/basics/single-systems) of the [Understanding Quantum Information and Computation](https://www.youtube.com/watch?v=0Av89fZenSY) course. The assumed background is a facility with linear algebra, and later problems also ask for mathematical arguments, i.e., proofs. You will also benefit from doing the previous problem set for classical information, though this is not strictly necessary. Feel free to try out the problems and decide whether they are a good fit for you.
#
# ### Learning goals
#
# 1. Decide whether or not a given mathematical object can represent a quantum state or quantum operation.
# 2. Read and express quantum states and operations in both matrix and Dirac representations.
# 3. Convert between matrix and Dirac representations of linear transformations.
# 4. Understand the essential definitions which occur frequently in quantum information.
# 5. Reason about general properties of state vectors and unitary operations.
# 6. Recognize the parallels in the mathematics of classical and quantum systems.

# %% [markdown]
# ## Mathematical skills development
# <font size ='4'>
# The problems in this section help develop the essential mathematics of single quantum systems. Learning goals 1-3 of the "Overview" section are in particular focus.
# </font>

# %% [markdown]
# <br><br>
# <b><font size = '6'> Recognizing quantum state vectors </font></b>
# <br><br>
# <font size = '3'>
# Decide whether each of the vectors below is a valid quantum state vector, meaning it may be used to represent a quantum state. Recall that quantum state vectors are complex vectors with Euclidean norm equal to one.
# </font>

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 1. A classic example
#
# <!-- ::: q-quiz(goal="Recognizing-state-vectors-1") -->
#
# <!-- ::: .question -->
#
# $$\begin{pmatrix}
#     \frac{1}{3} \\
#     \frac{1}{6} \\
#     \frac{1}{2}
# \end{pmatrix}$$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Valid
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Invalid
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     While this vector could represent a probabilistic system, it cannot represent a quantum system. The Euclidean norm of the vector is given by
# $$
#     \sqrt{\left(\frac{1}{3}\right)^2 + \left(\frac{1}{6}\right)^2 + \left(\frac{1}{2}\right)^2} = \sqrt{\frac{1}{9} + \frac{1}{36} + \frac{1}{4}}.
# $$
# Do we need to actually compute the rightmost sum above, or can we see right away that the answer won't be 1?
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 2. A complex example
#
# <!-- ::: q-quiz(goal="Recognizing-state-vectors-2") -->
#
# <!-- ::: .question -->
#
# $$\frac{1}{2} \vert\text{sitting}\rangle - \frac{1}{\sqrt{2}} \vert\text{standing}\rangle + \frac{i}{2} \vert\text{laying down}\rangle$$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Valid
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Invalid
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     Let's compute the Euclidean norm, taking $\vert \text{sitting} \rangle$, $\vert \text{standing} \rangle$, and $\vert \text{laying down} \rangle$ to be standard basis vectors corresponding to the classical configurations. Since the "laying down" coefficient is complex, we will have to take care to use absolute values when computing the Euclidean norm. We have
# $$
# \begin{aligned}
# \left\| \frac{1}{2} \vert\text{sitting}\rangle - \frac{1}{\sqrt{2}} \vert\text{standing}\rangle + \frac{i}{2} \vert\text{laying down}\rangle\right\|^2 &= \left\vert\frac{1}{2}\right\vert^2 + \left\vert-\frac{1}{\sqrt{2}}\right\vert^2 + \left\vert\frac{i}{2}\right\vert^2 \\
# &= \frac{1}{4} + \frac{1}{2} + \frac{1}{4} = 1.
# \end{aligned}
# $$
# This shows that the vector has unit norm, hence is a quantum state vector.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 3. Schrodinger's cat?
#
# <!-- ::: q-quiz(goal="Recognizing-state-vectors-3") -->
#
# <!-- ::: .question -->
#
# $$(\vert\text{alive}\rangle + 3\vert\text{dead}\rangle + 3\vert\text{alive}\rangle)/5$$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Valid
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Invalid
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     We are assuming the configurations "alive" and "dead" are the classical configurations for whatever living system is (sadly) under study. We first notice that two of the terms are proportional to the "alive" vector, so we first add those together to get$(4\vert\text{alive}\rangle + 3\vert\text{dead}\rangle)/5$. Now we compute the Euclidean norm (squared).
# $$
#     \left(\frac{4}{5}\right)^2 + \left(\frac{3}{5}\right)^2 = \frac{16}{25} + \frac{9}{25} = 1
# $$
# Thus, the Euclidean norm is one, and therefore this vector can represent a quantum state.
#
# Some readers might be troubled by the fact that we are claiming this system, which is assigned biological labels such as "alive" and "dead", can have anything to do with quantum mechanics. The point of this exercise is not to suggest that such superpositions occur in our regular experience, but rather that the labels themselves are not so important from the mathematical point of view. Whether or not a quantum description can be successfully applied is a different question: here we are just practicing using the formal mathematics.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 4.
#
# <!-- ::: q-quiz(goal="Recognizing-state-vectors-4") -->
#
# <!-- ::: .question -->
#
# $$ \frac{6}{\sqrt{2}} \begin{pmatrix}1 \\ -4\end{pmatrix} - \frac{1}{\sqrt{2}} \begin{pmatrix}5 \\ -23\end{pmatrix}
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Valid
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Invalid
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     This vector is complicated as written, so let's simplify. Let's first distribute the coefficient in front of each vector in the sum to get
# $$ \begin{pmatrix}
#     6/\sqrt{2} \\
#     -24/\sqrt{2}
#    \end{pmatrix} + \begin{pmatrix}
#        -5/\sqrt{2} \\
#        23/\sqrt{2}
#    \end{pmatrix}.
# $$
# Now we can add them entry by entry and factor out a $1/\sqrt{2}$ for notational simplicity.
# $$ \begin{pmatrix}
#     \frac{6}{\sqrt{2}} - \frac{5}{\sqrt{2}} \\
#     -\frac{24}{\sqrt{2}} + \frac{23}{\sqrt{2}}
#     \end{pmatrix} = \frac{1}{\sqrt{2}} \begin{pmatrix}
#     1 \\
#     -1
#     \end{pmatrix}
# $$
# In this (much simplified) form, we can readily check that the vector is properly normalized, therefore it represents a valid quantum state. Each entry corresponds to probability 1/2 according to the Born rule.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 5. Superpositions
#
# <!-- ::: q-quiz(goal="Recognizing-state-vectors-5") -->
#
# <!-- ::: .question -->
#
# $$ \frac{1}{\sqrt{2}} \vert 0 \rangle + \frac{1}{\sqrt{2}} \vert +\rangle
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Valid
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Invalid
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     This one is not a valid quantum state, despite appearances! The issue is $\vert+\rangle$ does not correspond to one of our classical states, but rather a superposition of classical states $\vert 0 \rangle + \vert 1 \rangle$ (properly normalized). Writing this out more explicitly, our vector becomes
# $$
#    \frac{1}{\sqrt{2}} \vert 0 \rangle + \frac{1}{\sqrt{2}} \left(\frac{1}{\sqrt{2}}\vert 0 \rangle + \frac{1}{\sqrt{2}}\vert 1 \rangle\right) \\
#    \frac{1+\sqrt{2}}{2} \vert 0\rangle + \frac{1}{2}\vert 1\rangle.
# $$
# In this form, we can compute the Euclidean norm straightforwardly.
# $$
#     \left\|\frac{1+\sqrt{2}}{2} \vert 0\rangle + \frac{1}{2}\vert 1\rangle\right\|^2 = \left(\frac{1 + \sqrt{2}}{2}\right)^2 + \frac{1}{4} = 1 + \frac{1}{\sqrt{2}} \neq 1.
# $$
# The square of the Euclidean norm is not one, so neither is the norm itself. Hence this is not a quantum state vector.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 6. Another superposition
#
# <!-- ::: q-quiz(goal="Recognizing-state-vectors-6") -->
#
# <!-- ::: .question -->
#
# $$\frac{1}{\sqrt{2}} \vert 0 \rangle + \frac{i}{\sqrt{2}} \vert -\rangle
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Valid
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Invalid
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     If you did the previous exercise, you may be surprised to find that this state is, in fact, properly normalized and hence a valid state vector. Let’s walk through the calculation. First, we write out $\vert - \rangle$ in terms of the classical states $\vert 0 \rangle, \vert 1\rangle$.
# $$
#    \frac{1}{\sqrt{2}} \vert 0 \rangle + \frac{i}{\sqrt{2}}\left(\frac{1}{\sqrt{2}}\vert 0 \rangle - \frac{1}{\sqrt{2}}\vert1\rangle\right)
# $$
# After regrouping terms,
# $$
#     \left(\frac{1}{\sqrt{2}} + \frac{i}{2}\right) \vert 0 \rangle - \frac{i}{\sqrt{2}} \vert 1 \rangle,
# $$
# we may directly compute the Euclidean norm.
# $$
#     \left\|\left(\frac{1}{\sqrt{2}} + \frac{i}{2}\right) \vert 0 \rangle - \frac{i}{\sqrt{2}} \vert 1 \rangle\right\|^2 = \left\vert \frac{1}{\sqrt{2}} + \frac{i}{2}\right\vert^2 + \left\vert \frac{-i}{2} \right\vert^2 = \frac{1}{2} + \frac{1}{4} + \frac{1}{4} = 1
# $$
# We see that the vector has unit nor, hence is a unit vector. This vector therefore represents a valid quantum state. What are the probabilities for measuring each outcome?
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block -->
#
# ### Concept check
#
# <font size = '3'>
# When checking whether a vector has Euclidean norm equal to one, do we have to take the square root, as the definition states? Why or why not?
# </font>
#
# <!-- ::: -->
#
# <br>

# %% [markdown]
# <br><br>
# <b><font size = '6'> Recognizing unitary transformations </font></b>
# <br><br>
# <font size = '3'>
# Which of the following might represent a unitary transformation of a quantum system? Recall that a matrix is unitary if it transforms quantum state vectors into quantum state vectors of the same dimension (i.e., number of entries).
# </font>

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 1. Symmetric
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-1") -->
#
# <!-- ::: .question -->
#
# $$\begin{pmatrix}
#     0 & 0 & 1 \\
#     0 & 1 & 0 \\
#     1 & 0 & 0
# \end{pmatrix}$$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     Yes, this is a valid unitary. Let's call this matrix $M$. First, we can notice that $M$ is real and symmetric, so $M^\dagger = M$. Therefore, we just need to check that $M^2 = \mathbb{1}$. (Why is that?)
#
# Here's a calculation showing exactly that:
# $$
#     M^2 = \begin{pmatrix}
#     0 & 0 & 1 \\
#     0 & 1 & 0 \\
#     1 & 0 & 0
#     \end{pmatrix} \begin{pmatrix}
#     0 & 0 & 1 \\
#     0 & 1 & 0 \\
#     1 & 0 & 0
#     \end{pmatrix} = \begin{pmatrix}
#     1 & 0 & 0 \\
#     0 & 1 & 0 \\
#     0 & 0 & 1
#     \end{pmatrix} = \mathbb{1}.
# $$
# Since the result is the identity, we are done.
#
# There's another way we could have seen that $M^2 = \mathbb{1}$ without a matrix calculation. In words, $M$ interchanges the first and third standard basis vectors, leaving the second one alone. Doing this interchange twice ($M^2$) leaves everything unchanged ($\mathbb{1}$).
#
# More generally still, $M$ is a permutation matrix, meaning it simply rearranges ('permutes') standard basis vectors. Any such matrix is unitary. Can you see why?
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 2. Hadamard?
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-2") -->
#
# <!-- ::: .question -->
#
# $$\begin{pmatrix}
#     1/\sqrt{2} & 1/\sqrt{2} \\
#     1/\sqrt{2} & -1/\sqrt{2} \\
#     0 & 0
# \end{pmatrix} = \frac{1}{\sqrt{2}} \begin{pmatrix}
#     1 & 1 \\
#     1 & -1 \\
#     0 & 0
# \end{pmatrix}
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# No, this is not a unitary matrix. It cannot be, because it is not a square matrix!
#
# Interestingly, this matrix is an <i>isometry</i>, in that it takes vectors of Euclidean norm one to other vectors of norm one. It just doesn’t take them back! More precisely, if we call our matrix $M$, we have $M^\dagger M = \mathbb{1}$, since
# $$
#     M^\dagger M = \frac{1}{2}\begin{pmatrix}
#     1 & 1 & 0 \\
#     1 & -1 & 0
#     \end{pmatrix} \begin{pmatrix}
#     1 & 1 \\
#     1 & -1 \\
#     0 & 0
#     \end{pmatrix} = \begin{pmatrix}
#     1 & 0 \\
#     0 & 1
#     \end{pmatrix} = \mathbb{1}.
# $$
# However, the other direction does not hold: $M M^\dagger \neq \mathbb{1}$. Feel free to explore this yourself. We might say that $M^\dagger$ is a <i>left</i> inverse of $M$ but not a <i>right</i> inverse. For $M$ to be unitary, we must have it both ways.
#
# For square matrices, $M M^\dagger = \mathbb{1}$ does imply that $M^\dagger M = \mathbb{1}$. However, we must remember that this useful property only holds for square martrices.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 3. A toss up
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-3") -->
#
# <!-- ::: .question -->
#
# $$ \vert \text{heads} \rangle \langle \text{tails} \vert + \vert \text{tails} \rangle \langle \text{heads} \vert
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     Yes, this is unitary! In fact, it is essentially the NOT gate under relabeling. If we assign "heads" and "tails" the column vectors
# $$
#     \vert \text{heads} \rangle = \begin{pmatrix} 1 \\ 0 \end{pmatrix},
#     \quad \vert\text{tails}\rangle = \begin{pmatrix} 0 \\ 1 \end{pmatrix}
# $$
# then the matrix becomes
# $$
# \begin{aligned}
#     \vert\text{heads}\rangle\langle\text{tails}\vert + \vert\text{tails}\rangle\langle\text{heads}\vert &=
#     \begin{pmatrix} 1 \\ 0 \end{pmatrix} \begin{pmatrix} 0 & 1 \end{pmatrix} +
#     \begin{pmatrix} 0 \\ 1 \end{pmatrix} \begin{pmatrix} 1 & 0 \end{pmatrix} \\
#     &=
#     \begin{pmatrix} 0 & 1 \\ 0 & 0 \end{pmatrix} + \begin{pmatrix}0 & 0 \\ 1 & 0\end{pmatrix} \\
#     &= \begin{pmatrix} 0 & 1 \\ 1 & 0\end{pmatrix}.
# \end{aligned}
# $$
# How can we see this is unitary? We can recognize it as the Pauli $X$ matrix, or do a direct computation. Try to take it from this point!
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 4. A complex example
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-4") -->
#
# <!-- ::: .question -->
#
# $$ \frac{1}{\sqrt{3}} \begin{pmatrix}
#     i & 2 & 0 \\
#     2 & -i & 0 \\
#     0 & 0 & \sqrt{3}
# \end{pmatrix}
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     This matrix is not unitary. Let's call it $M$. The adjoint $M^\dagger$ is given by
# $$
#     M^\dagger = \frac{1}{\sqrt{3}}\begin{pmatrix}
#         i & 2 & 0 \\
#         2 & -i & 0 \\
#         0 & 0 & \sqrt{3}
#     \end{pmatrix}^\dagger = \frac{1}{\sqrt{3}} \begin{pmatrix}
#         -i & 2 & 0 \\
#         2 & i & 0 \\
#         0 & 0 & \sqrt{3}
#     \end{pmatrix}
# $$
# which we see amounts to taking the complex conjugate of the only two imaginary entries. Now we compute $M^\dagger M$ and check whether we get the identity.
# $$
# \begin{aligned}
#     M^\dagger M = \frac{1}{3} \begin{pmatrix}
#         -i & 2 & 0 \\
#         2 & i & 0 \\
#         0 & 0 & \sqrt{3}
#     \end{pmatrix} \begin{pmatrix}
#         i & 2 & 0 \\
#         2 & -i & 0 \\
#         0 & 0 & \sqrt{3}
#     \end{pmatrix} &= \frac{1}{3} \begin{pmatrix}
#         1 + 4 & -4i & 0 \\
#         2i + 2i & 4 + 1 & 0 \\
#         0 & 0 & 3
#     \end{pmatrix} \\
#     &= \begin{pmatrix}
#         5/3 & -4i/3 & 0 \\
#         4i/3 & 5/3 & 0 \\
#         0 & 0 & 1
#     \end{pmatrix} \\
#     &\neq I
# \end{aligned}
# $$
# Since we did not get the identity, $M$ is not unitary. We didn't need to compute the full matrix actually; once we knew the result wouldn't be $I$, we could have stopped. Note that care must be taken when solving this problem, because if we forgot to take the complex conjugate of the entries due to the adjoint, we would get the wrong answer. This is because $M^T=M$ and $M^2=I$. Feel free to check these properties yourself if you’re curious.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 5. Adding Pauli's, part one.
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-5") -->
#
# <!-- ::: .question -->
#
# $$ \frac{\sigma_x + \sigma_z}{2}
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     This matrix is not unitary. This could be checked in the usual way: expressing everything as a matrix, computing the Hermitian conjugate and multiplying them to see if you get the identity. Alternatively, we can use the following very important properties of the Pauli matrices.
# $$
#     \sigma_x^2 = \sigma_z^2 = I, \quad \sigma_z \sigma_x = -\sigma_x \sigma_z
# $$
# Noting that the Pauli's are their own Hermitian conjugate ($\sigma_i^\dagger = \sigma_i$), we just need to compute the square of the matrix.
# $$
#     \left(\frac{\sigma_x + \sigma_z}{2}\right)^2 = \frac{1}{4} (\sigma_x^2 + \sigma_z^2 + \sigma_x \sigma_z + \sigma_z \sigma_x) = \frac{1}{4} (\mathbb{1} + \mathbb{1} + 0) = \mathbb{1}/2
# $$
# But clearly $\mathbb{1}/2 \neq \mathbb{1} \neq $, so it appears our matrix is not unitary. As a bonus, how can you modify this matrix, in a simple way, such that it is, in fact, unitary?
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 6. Look familiar?
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-6") -->
#
# <!-- ::: .question -->
#
# $$\vert 1 \rangle \langle 1 \vert + \vert 0 \rangle \langle 0 \vert
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     Yes, in fact, this matrix is the identity matrix! (Why is the identity unitary?) If you're not sure, write it in matrix form, or multiply it by a vector and see the result.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 7. Adding Paulis, part 2.
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-7") -->
#
# <!-- ::: .question -->
#
# $$ \frac{\sigma_x + \sigma_y}{\sqrt{2}}
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# This matrix is unitary! To see why, let's follow a similar line of reasoning as we did in the answer to Problem 5 (take a look at that problem if you haven't yet). Since the algebraic properties discusses there remain the same when we exchange $\sigma_z$ for $\sigma_y$, the only essential difference is that the factor of $1/2$ has been replaced with $1/\sqrt{2}$. But this makes all the difference in the calculation, since we'll get $\mathbb{1}$ instead of $\mathbb{1}/2$. Try to retrace the steps of Problem 5 to come to this conclusion!
#
# There is something deeper going on here. We can think of a matrix $a \sigma_x + b \sigma_y + c \sigma_z$, where $a, b, c$ are real numbers, as a 3-dimensional vector $(a,b,c)$. It turns out that unitarity of the matrix is related to the vector $(a,b,c)$ being *normalized*. If you're curious, check out the "Diving Deeper" section of the problem set, under "When are linear combinations of Paulis unitary?".
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 8. Strange notation
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-8") -->
#
# <!-- ::: .question -->
#
# $$\vert + \rangle \langle + \vert + \vert - \rangle \langle - \vert
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Surprise, this is just the identity matrix! Do you see the resemblance to problem 6? This is an instance of a <i>resolution of the identity</i>, meaning we "resolve" the identity in terms of some (orthonormal) basis. You can check this by expanding everything out and converting to matrix form. With a few additional conceptual tools, there is another way to understand exactly why we get the identity matrix.
#
# Indeed, $\vert + \rangle$ and $\vert - \rangle$ form an "orthonormal" basis, meaning the vectors have norm one and they are also orthogonal: $\langle + \vert - \rangle = 0$. For any orthonormal basis $\{\vert v_1 \rangle, \vert v_2 \rangle\}$ the matrix
# $$
#     \vert v_1 \rangle \langle v_1 \vert + \vert v_2 \rangle \langle v_2 \vert
# $$
# is the identity. This fact generalizes to arbitrary dimensions $n$, not just $n = 2$. This fact will become more apparent in the [Quantum Circuits](https://learn.qiskit.org/course/basics/quantum-circuits) chapter, when we more clearly introduce idea of an inner product.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 9. Can you see it?
#
# <!-- ::: q-quiz(goal="Recognizing-unitaries-9") -->
#
# <!-- ::: .question -->
#
# $$\begin{bmatrix}
#     1 & 1 \\
#     i & i
# \end{bmatrix}
# $$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# Unitary
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Not unitary
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# The matrix is not unitary. In fact, it is not even invertible! Why must unitary matrices be invertible? Why is this matrix not invertible? (Hint: are the columns of the matrix linearly independent?)
#
# Notice we used square brackets $[\cdot]$ to enclose the matrix, instead of the usual parenthetical $(\cdot)$ brackets. This is simply to familarize you with other common notations for the same object.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# ### Converting from matrix to Dirac notation
#
# Write the following matrices in Dirac notation.

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 1. Count off
#
# $$\begin{pmatrix}
#     5 & 6 \\
#     7 & 8
# \end{pmatrix}
# $$
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Because the matrix is $2\times 2$, we can choose any two symbols to denote the classical states. Here we'll choose the symbols $a$ and $b$, rather than the more conventional bits 0 and 1, to emphasize this choice is arbitrary.
#
# Every element in the matrix corresponds to a specific row and column, and these rows and columns are labelled by the classical state set. For example, the "6" in the matrix above is in row $a$ and column $b$. We can "pick out" the element in Dirac notation by constructing a matrix whose only nonzero entry is the top right. In our case, this is given by
#
# $$\vert a \rangle \langle b \vert = \begin{pmatrix}
#     0 & 1 \\
#     0 & 0
# \end{pmatrix}.
# $$
#
# We can construct the full matrix from "outer products" such as these. To start, we can multiply $\vert a \rangle \langle b \vert$ by 6 to give it the correct value. Then we could add it to, say $5 \vert a \rangle \langle a \vert$. This gives the correct top row. Continuing this procedure we will find that
# $$\begin{pmatrix}
#     5 & 6 \\
#     7 & 8
# \end{pmatrix} = 5 \vert a \rangle \langle a \vert + 6 \vert a \rangle \langle b \vert + 7 \vert b \rangle \langle a \vert + 8 \vert b \rangle \langle b \vert.
# $$
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 2. The Hadamard operation
#
# $$ H = \frac{1}{\sqrt{2}} \begin{pmatrix}
#     1 & 1 \\
#     1 & -1
# \end{pmatrix}
# $$
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# We'll take the binary 0, 1 to represent our two states, since the Hadamard is a quantum gate. We have a basis for matrices given by $\vert 0\rangle \langle 0 \vert, \vert 0\rangle \langle 1 \vert, \vert 1\rangle \langle 0 \vert,$ and $\vert 1\rangle \langle 1 \vert$. That means we will expect an answer of the form
# $$ H = \;\;\fbox{?} \;\vert 0\rangle \langle 0 \vert \;\;+ \fbox{?} \;\vert 0\rangle \langle 1 \vert \;\;+ \fbox{?} \;\vert 1\rangle \langle 0 \vert \;\;+ \fbox{?} \;\vert 1\rangle \langle 1 \vert.
# $$
# Each of these terms only has one nonzero entry. So we simply need to multiply each by the correct coefficient in the matrix $H$. This leads to our final answer
# $$ H = \frac{1}{\sqrt{2}}\big(\vert 0\rangle \langle 0 \vert + \vert 0\rangle \langle 1 \vert + \vert 1\rangle \langle 0 \vert - \vert 1\rangle \langle 1 \vert\big).
# $$
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 3. The identity matrix
#
# The identity matrix on a space with classical state set $\Gamma$.
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# The identity $\mathbb{1}$ is the matrix whose entries are all zero except on the diagonal, in which case the entries are one. We don't know the size of $\Gamma$, but as usual we suppose it's finite. If there are, say, $n$ states in $\Gamma$, we can enumerate these states as $\gamma_1, \gamma_2, \dots, \gamma_n$. For any matrix $M$, we can express $M$ as a linear combination of terms of the form $\vert \gamma_i \rangle \langle \gamma_j \vert$. The thing is, there are no off diagonal elements of $I$, so we don't need terms for $i \neq j$. We can just include terms which look like $\vert \gamma_i \rangle \langle \gamma_i \vert$. This gives us something like
# $$I = \sum_{i = 1}^n c_i \; \vert \gamma_i \rangle \langle \gamma_i \vert.
# $$
# We just need to determine $c_i$. All the $c_i$ should probably be equal, since the identity doesn't treat any vector more special than others. In fact, we can see that the $c_i$ are simply the diagonal elements of $I$, which are just 1. Hence,
# $$I = \sum_{i=1}^n  \vert \gamma_i \rangle \langle \gamma_i \vert.
# $$
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 4. The Pauli y matrix.
#
# $$ \sigma_y = \begin{pmatrix}
#     0 & -i \\
#     i & 0
# \end{pmatrix}
# $$
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Only the off diagonals are nonzero, so we have to include $\vert 0 \rangle \langle 1 \vert$ and $\vert 1 \rangle \langle 0 \vert$, but that is it. Each of these gets multiplied by the appropriate matrix element, leading to
# $$ \sigma_y = -i \vert 0 \rangle \langle 1 \vert + i \vert 1 \rangle \langle 0 \vert.
# $$
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <br><br>
# <b><font size = '6'> Computing unitary operations </font></b>
# <br><br>
# <font size = '3'>
# In each of these situations, compute the resulting quantum state by hand. Check that your result is properly normalized.
# </font>

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 1. A common example
#
# The Hadamard operation applied to the state $\vert+i\rangle = \frac{1}{\sqrt{2}}(\vert 0 \rangle + i\vert 1 \rangle)$.
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Using geometric ideas from the so-called "Bloch sphere", there is a relatively straightforward way to get the answer. But fear not, we can still answer this question in the usual way: compute it! Recall that the Hamadard $H$ acts on the basis states $\vert 0 \rangle$ and $\vert 1 \rangle$ as follows.
# $$ H \vert 0 \rangle = \frac{1}{\sqrt{2}}\left(\vert 0 \rangle + \vert 1 \rangle\right) \\
# H \vert 1 \rangle = \frac{1}{\sqrt{2}}\left(\vert 0 \rangle - \vert 1 \rangle\right).
# $$
# Hence,
# $$
# \begin{aligned}
#     H \vert +i \rangle &= \frac{1}{\sqrt{2}}\left(H \vert 0 \rangle + i H \vert 1 \rangle\right) \\
#     &= \frac{1}{2}\left( \vert 0 \rangle + \vert 1 \rangle + i \vert 0 \rangle  - i \vert 1 \rangle\right) \\
#     &= \frac{1 + i}{2} \vert 0 \rangle + \frac{1-i}{2} \vert 1 \rangle.
# \end{aligned}
# $$
# This is a perfectly acceptable answer to the question, and we can stop here. Nevertheless, we can obtain a bit more insight, if we're looking for it, by some algebraic manipulations using the Euler identity.
# $$ e^{i \theta} = \cos\theta = i \sin\theta
# $$
# In particular, using the fact that
# $$ \frac{1 + i}{2} = \frac{1}{\sqrt{2}} e^{i\pi/4}, \qquad \frac{1 - i}{2} = \frac{1}{\sqrt{2}} e^{-i\pi/4}
# $$
# we have
# $$
# \begin{aligned}
#     H \vert +i \rangle &= \frac{1}{\sqrt{2}} \left(e^{i\pi/4} \vert 0 \rangle + e^{-i\pi/4} \vert 1 \rangle\right) \\
#     &= \frac{e^{i\pi/4}}{\sqrt{2}} \left(\vert 0 \rangle + e^{-i\pi/2} \vert 1 \rangle\right) \\
#     &= \frac{e^{i\pi/4}}{\sqrt{2}} \left(\vert 0 \rangle -i\vert 1 \rangle\right) = e^{i\pi/4} \vert -i \rangle.
# \end{aligned}
# $$
# Here we've used the fact that $e^{-i\pi/2} = -i$, and defined $\vert - i \rangle$ analogously to $\vert + i\rangle$ (can you see how)?
#
# This way of displaying things is interesting because, as it happens, $\vert+i\rangle$ and $\vert-i\rangle$ are eigenvectors of $\sigma_y$. If the importance of this is still mysterious, don't fret! We are just building up some computational tools.
# </details>
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 2. A not-so-common example
#
# The matrix
#
# $$U = \frac{1}{2} \begin{pmatrix}
#     1 & 1 & 1 & 1 \\
#     1 & i & -1 & -i \\
#     1 & -1 & 1 & -1 \\
#     1 & -i & -1 & i
# \end{pmatrix}$$
#
# applied to the state
#
# $$\vert\psi\rangle = \begin{pmatrix}
#     1 \\
#     2 \\
#     3 \\
#     4
# \end{pmatrix} \frac{1}{\sqrt{30}}.$$
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     To simplify matters, let's collect the factors of $\frac{1}{2}$ and $\frac{1}{\sqrt{30}}$ "out front". We are left with a typical matrix-vector multiplication. It is possible to do such a calculation on a computer, but it is helpful to know how to do such simple examples by hand.
#
# The result of this remaining calculation will be a column vector of four entries. The topmost entry is $1\times 1 + 1\times 2 + 1\times 3 + 1\times 4 = 10$. The second entry is given by
# $$\begin{pmatrix}
#     1 & i & -1 & -i
# \end{pmatrix} \begin{pmatrix}
# 1 \\
# 2 \\
# 3 \\
# 4
# \end{pmatrix} = 1 + 2i -3 -4i = -2(1 + i) = -2 \sqrt{2} e^{i\pi/4}
# $$
# the last step is a nice little trick using Euler's formula
# $$ \cos\theta + i \sin\theta = e^{i\theta}
# $$
# which implies
# $$ \frac{1}{\sqrt{2}}(1 + i) = e^{i\pi/4}
# $$
# but isn't necessary. Calculating the remaining elements is straightforward and the result is
# $$\begin{pmatrix}
#     10 \\
#     -2 \sqrt{2} e^{i\pi/4} \\
#     -2 \\
#     -2 \sqrt{2} e^{-i\pi/4}
# \end{pmatrix}.
# $$
# Now let's remember to include the scaling factors we've left out. Our final answer is
# $$ U \vert \psi \rangle = \frac{1}{2 \sqrt{30}} \begin{pmatrix}
#     10 \\
#     -2 \sqrt{2} e^{i\pi/4} \\
#     -2 \\
#     -2 \sqrt{2} e^{-i\pi/4}
# \end{pmatrix}
# $$
# Now that we have an answer, it's good to check that it has the same normalization as $\vert \psi \rangle$. Try this yourself and see that the norm is still 1. For this step, especially, it was helpful to convert to the exponential forms in the second and fourth coefficients, but not necessary.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# ## Conceptual understanding
#
# The problems of this section are intended to develop a conceptual understanding of the material, with particular focus on Learning Goals 4-6 given in the Overview.

# %% [markdown]
# <b><font size = '6'>Definitional problems </font></b>
#
# <font size = '3'>
# Knowing terminology by heart is not the end-all goal, but gaining a familiarity with standard language helps make understanding complicated ideas easier down the line. Use the exercises below to get practice with common jargon used in quantum information.
# </font>

# %% [markdown]
# <b><font size = '4'>Definition multiple choice</font></b>

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 1. Probabilities from amplitudes
#
# <!-- ::: q-quiz(goal="Definition-MC-1") -->
#
# <!-- ::: .question -->
#
# In quantum mechanics, the Born rule tells us that the probability of measuring classical state $a$, with entry $c_a$ in the state vector, is given by
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# the square of $c_a$.
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# the entry $c_a$.
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# the absolute value of $c_a$.
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# the square of the absolute value of $c_a$.
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# the cube of the absolute value of $c_a$.
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 2.
#
# <!-- ::: q-quiz(goal="Definition-MC-2") -->
#
# <!-- ::: .question -->
#
# A linear transformation $M$ is unitary if and only if it is invertible, with inverse equal to its
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# conjugate transpose.
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# adjoint.
#
# <!-- ::: -->
#
#
# <!-- ::: .option -->
#
# Hermitian conjugate.
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# All of the other answers.
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# All of the choices given can refer to the same thing. Oftentimes, the word used depends on the community. "Conjugate transpose" is the most concrete description, especially when $M$ is given in matrix form. "Adjoint" is more commonly used in mathematical circles, while "Hermitian conjugate" is typically used in physics.
#
# It is also worth mentioning that, in addition to the dagger symbol $\dagger$, the star $*$ is also used for adjoints, especially among mathematicians. Unfortunately, physicists often use this same symbol to represent complex conjugation alone, without transposition. One must pay attention to the context to figure out what specific meaning is being used.
# </details>
# <!-- ::: -->

# %% [markdown]
# <b><font size = '4'>Fill in the blank</font></b>

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 1. Transformations
#
# For
# <details><summary>_</summary>classical</details>
# information, the relevant transformations of probability vectors are stochastic matrices, whereas for quantum information they are
# <details><summary>_</summary>unitary</details>
# matrices.
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 2. Quantum is "wavelike"
#
# In the context of quantum mechanics, a linear combination of state vectors which produces yet another state vector is typically called a
# <details><summary>_</summary>superposition</details>,
# in analogy with wave phenomena known to physicists prior to the 20th century.
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 3. Everything is normal.
#
# A
# <details><summary>_</summary>unit</details>
# vector is a vector which is
# <details><summary></summary>normalized</details>
# , so that it has norm equal to one. Vectors which are normalized with respect to the
# <details><summary>_</summary>Euclidean</details>
# norm are valid representations of quantum states.
#
# <!-- ::: -->

# %% [markdown]
# <b><font size = '4'>Flash cards</font></b>
#
# <font size = '3'>
# For each of the terms below, think about its meaning and as many associations as you can. Then click on the word to see the provided definition.
# </font>
#
# <!-- ::: q-block.reminder -->
#
# ### Quantum
#
# <details>
#     <summary><u><font size = '3'>_</font></u></summary>
#     Referring to ideas in physics developed since the early 20th century, in response to mounting empirical and theoretical evidence that the old "classical" descriptions were utterly flawed and insufficient.
# </details>
# <!-- ::: -->
#
# <!-- ::: q-block.reminder -->
#
# ### Unit vector
#
# <details>
#     <summary><u><font size = '3'>_</font></u></summary>
#     A vector whose norm equals one. Unit vectors with respect to the Euclidean norm can serve as valid representations of actual quantum states.
# </details>
# <!-- ::: -->
#
# <!-- ::: q-block.reminder -->
#
# ### Classical state set
#
# <details>
#     <summary><u><font size = '3'>_</font></u></summary>
#     The basic configurations a physical system can take on. These configurations are considered independent in the sense that, loosely speaking, a system that is in a definite classical cannot be in more than one such state.
# </details>
# <!-- ::: -->
#
# <!-- ::: q-block.reminder -->
#
# ### Quantum state vector
#
# <details>
#     <summary><u><font size = '3'>_</font></u></summary>
#     A representation of the state of a quantum system as a (column) vector, whose entries represent probabilities of certain classical states.
# </details>
# <!-- ::: -->
#
# <!-- ::: q-block.reminder -->
#
# ### Quantum system
#
# <details>
#     <summary><u><font size = '3'>_</font></u></summary>
#     Any substance or "system" found in nature whose properties can be suitably described as "quantum", meaning they are amenable to the mathematical treatment presented in these exercises and the text.
# </details>
# <!-- ::: -->
#
# <!-- ::: q-block.reminder -->
#
# ### Qubit
#
# <details>
#     <summary><u><font size = '3'>_</font></u></summary>
#     A quantum system with two classical states, typically denoted 0 and 1. Often used in the context of computation as the basic building block of a quantum computer.
# </details>
# <!-- ::: -->
#
# <!-- ::: q-block.reminder -->
#
# ### Unitary matrices
#
# <details>
#     <summary><u><font size = '3'>_</font></u></summary>
#     A matrix whose inverse equals its conjugate transpose. Equivalently, one which transforms any quantum state vector into another state vector. In quantum information,
# </details>
# <!-- ::: -->

# %% [markdown]
# <br><br>
# <b><font size = '6'> Conceptual true or false </font></b>
# <br><br>
# <font size = '3'>
# Use these questions to probe your conceptual understanding of the mathematics of quantum information.
# </font>

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 1. Sum of unitaries
#
# <!-- ::: q-quiz(goal="Conceptual-true-or-false-1") -->
#
# <!-- ::: .question -->
#
# The sum of two unitary matricees $U + W$ is also unitary.
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# True
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# False
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     This statement is false. To show this, we can come up with a counterexample. What is the simplest counterexample you can come up with? Think before reading on.
#
# <details>
#     <summary><u><font size = '2'>Counterexample</font></u></summary>
#     Let's take $U = W = I$, where $I$ is the identity matrix. (Stop and think here, why does this choice serve as counterexample?). While the identity matrix is unitary, $U + W = 2I$ is not unitary. One way to see this is that $2I$ doubles the Euclidean norm of any vector it multiplies.
# </details>
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 2. Products of unitaries
#
# <!-- ::: q-quiz(goal="Conceptual-true-or-false-2") -->
#
# <!-- ::: .question -->
#
# The products $UW$ of unitary matrices $U, W$ is also unitary.
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# True
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# False
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Yes, the product is also unitary. There are several ways to show this, and one way is to show that $(UW) (UW)^\dagger = I$. Note here that we don't need to also show that $(UW)^\dagger (UW) = I$. This is because $UW$ is a square matrix, and if $(UW) (UW)^\dagger = I$, then we know right away that $(UW)^\dagger = (UW)^{-1}$. Left inverses are also right inverses for square matrices.
#
# With that behind us, our final task is to show $(UW)(UW)^\dagger = I$. The important fact from linear algebra we will use is that $(AB)^\dagger = B^\dagger A^\dagger$ for any matrices $A, B$. We will also use the associative property of matrix multiplication. Let's put this all together:
#
# $$
# \begin{aligned}
#     (UW)(UW)^\dagger = (UW)(W^\dagger U^\dagger) &= U(W W^\dagger) U^\dagger \\
#     &= U I U^\dagger = U U^\dagger = I.
# \end{aligned}
# $$
#
# Hence, we see that $UW$ is unitary. This is an important fact, because matrix multiplication of two unitary operations represents the sequential application of those operations. One can think of applying one quantum gate after the other, in the context of quantum computing.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 3. Euclidean norm preservation
#
# <!-- ::: q-quiz(goal="Conceptual-true-or-false-3") -->
#
# <!-- ::: .question -->
#
# If a matrix $M$ preserves the Euclidean norm of every input vector $v$, i.e., $\| Mv\| =\| v\|$ for all $v$, then $M$ is unitary.
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# True
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# False
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     This is a trick question! Sometimes a matrix can preserve Euclidean norm ("length") by sending the vector to a space of higher dimension. As an example, consider the matrix
#
# $$ M = \begin{pmatrix}
#     1 & 0 \\
#     0 & 1 \\
#     0 & 0
# \end{pmatrix}.
# $$
#
# This matrix certainly preserves lengths, because it essentially embeds the plane in three dimensions (why?). However, notice we can't go the opposite way: this matrix is not invertible. But all unitary matrices are invertible!
#
# Technically, this matrix, and other Euclidean-norm-preserving matrices, are known as <i>isometries</i>. These are useful mathematical objects in quantum information theory, and all unitary matrices are isometries. But the converse is not true: not all isometries are unitary.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 4. Fully quantum
#
# <!-- ::: q-quiz(goal="Conceptual-true-or-false-4") -->
#
# <!-- ::: .question -->
#
# A quantum system has no classical states.
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# True
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# False
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# A quantum system having a "classical" state might sound like a paradox, since "quantum" and "classical" are often presented as opposites. In this context, however, remember that we build up quantum states from a set of classical states! Quantum features emerge when we take linear combinations, or superpositions, of the classical states. So, in fact, <i>every</i> quantum system has classical states, in our characterization.
#
# There is a reasonable objection to be made, however, that in practice it is not always obvious which *choice* of classical states is most natural. An example from physics comes particles with a property known as "spin", such as electrons. One usually defines the classical states as along some arbitrary axis in space (and calls it the "z-axis"), but the choice is arbitrary since space has no preferred direction.
#
# In any case, for the purposes of this series, the way we've constructed quantum systems from a classical state set is perfectly acceptable, and widely applicable.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 5. Stochastic and unitary
#
# <!-- ::: q-quiz(goal="Conceptual-true-or-false-5") -->
#
# <!-- ::: .question -->
#
# The only matrices that are both stochastic and unitary are permutation matrices.
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# True
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# False
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 6. More unitaries!
#
# <!-- ::: q-quiz(goal="Conceptual-true-or-false-6") -->
#
# <!-- ::: .question -->
#
# A matrix $M$ is unitary if $M^\dagger M = I$.
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# True
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# False
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
#     This is a similar trick to problem 3! We need the other condition: $M M^\dagger = I$. With $M^\dagger M = I$ alone, we are only guaranteed $M$ is an <i>isometry</i>. But it very well could be non-invertible, hence not unitary.
#
# Try to come up with your own counterexamples. Is there a matrix $M$, not unitary, but such that $M^\dagger M = I$?
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block -->
#
# ### Checking unitarity
#
# You and your friend Rosemary are working on a quantum computing task and need to verify whether a certain matrix $A$ is unitary. Rosemary is feeling short on time and is frustrated by the fact that $A$ must preserve the Euclidean norm for every vector. She has an idea to speed things up.
#
# > “It is obviously impossible to check that $A$ keeps the length of every single vector the same. The number of distinct vectors is infinite. Thankfully, $A$ is linear! Therefore, we only need to check things for the basis of classical states: the standard basis. By linearity, if $A$ keeps the length of standard basis vectors constant, $A$ will keep the length of every vector the same, and we’re done!”
#
# How would you respond to Rosemary’s suggestion? Do you think her proposal will work?
#
# * If so, prove it and verify with some examples.
# * Otherwise, come up with a counterexample. Where is the flaw in your friend's reasoning? Is there a more efficient way to check if $A$ is unitary than checking every case?
#
# <!-- ::: -->

# %% [markdown]
# ## Diving deeper

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Forgetting normalization in conserving norm
#
# Quantum state vectors have Euclidean norm ("length") one, and so the relevant set of transformations would necessarily preserve this norm. Could a matrix $M$ ever preserve the length of unit vectors, but not general vectors? If so, we might need to extend our notion of what counts as a valid transformation, beyond that of just unitary operations.
#
# In fact, this is not the case. Show that any linear transformation $M$ which preserves unit vectors necessarily preserves the norm of any vector, and is therefore unitary. Thus, unitaries truly represent a natural class of valid quantum operations.
#
# <details>
#     <summary><font size = '2'><u>Answer with explanation</u></font></summary>
#     Suppose $M$ is a unit-vector-preserving operation. Let $\vert\psi\rangle$ be an <i>arbitrary</i> vector in the space which $M$ acts on. Although $\vert\psi\rangle$ is not unit length, it is proportional to a vector of unit length. That is, there is a unit vector $\vert \phi \rangle$ and a nonnegative constant $c$ such that $\vert\psi\rangle = c \vert \phi \rangle$. For any norm $\| \cdot \|$, one has that $\| c \vert \phi\rangle \| = \lvert c\rvert \| \vert \phi\rangle \|$. In our case, $\lvert c\rvert  = c$ and $\| \vert \phi\rangle \| = 1$. Hence, $c = \| \vert \psi \rangle \|$.
#
# Consider the action of $M$ on $\vert \psi\rangle = c \vert\phi \rangle$. By linearity, $M \vert \psi \rangle = c M \vert \phi \rangle$. Moreover,
# $$
#     \| c M \vert\phi\rangle \| = c \| M \vert\phi\rangle \|.
# $$
# By assumption, $\| M \vert\phi\rangle \| =1$, so altogether we have $\| M \vert\psi\rangle\| = c$. But we already concluded that $c = \| \vert \psi \rangle \|$. Thus, $\| M \vert\psi\rangle\| = \| \vert \psi\rangle\|$. Since $\vert\psi\rangle$ was arbitrary, we conclude that $M$ preserves the length of every vector in the vector space.
#
#
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <font size = '6'> When are linear combinations of Paulis unitary?</font>
#
# In problems 5 and 7 of "Recognizing unitary transformations", we looked at some examples of linear combinations of Pauli matrices, such as $\frac{1}{2}\sigma_x  + \frac{1}{2}\sigma_z$, and asked whether they were unitary. We might like to know more generally: under what conditions is a linear combination of Pauli matrices unitary?
#
# Before diving in, it will be helpful to learn some essential properties of the Pauli matrices. For notational simplicity (and to introduce you to alternative, common notation), we will use the capital letters $X, Y, Z$ to denote the Pauli matrices instead of $\sigma_x, \sigma_y, \sigma_z$ for this activity.
#
# <!-- ::: q-block.exercise -->
#
# ### 1. The Pauli Algebra
# a) Show that the Pauli matrices *anticommute*.
#
# $$ XY = - YX \qquad YZ = -ZY \qquad ZX = - XZ
# $$
#
# <details>
#     <summary><u><font size = '2'>Answer to a)</font></u></summary>
# We will just show the first of these, the others can be checked by the same matrix multiplication. We have
# $$ XY = \begin{pmatrix}
#     0 & 1 \\
#     1 & 0
# \end{pmatrix} \begin{pmatrix}
#     0 & -i \\
#     i & 0
# \end{pmatrix} = \begin{pmatrix}
#     i & 0 \\
#     0 & -i
# \end{pmatrix}.
# $$
# Meanwhile,
# $$
#     YX = \begin{pmatrix}
#     0 & -i \\
#     i & 0
# \end{pmatrix} \begin{pmatrix}
#     0 & 1 \\
#     1 & 0
# \end{pmatrix} = \begin{pmatrix}
#     -i & 0 \\
#     0 & i
# \end{pmatrix}
# $$
# Comparing the two results, we see they are negatives of each other: $XY = - YX$. See if you can do the rest yourself!
# </details>
#
# b) Show that each of the Pauli matrices squares to the identity.
#
# $$ X^2 = Y^2 = Z^2 = \mathbb{1}.
# $$
#
# <details>
#     <summary><u><font size = '2'>Answer to b)</font></u></summary>
# Each of these can be done with direct matrix multiplication.
# $$ X^2 = \begin{pmatrix}
#     0 & 1 \\
#     1 & 0
# \end{pmatrix}\begin{pmatrix}
#     0 & 1 \\
#     1 & 0
# \end{pmatrix} = \begin{pmatrix}
#     1 & 0 \\
#     0 & 1
# \end{pmatrix} = \mathbb{1}\\
# Y^2 = \begin{pmatrix}
#     0 & -i \\
#     i & 0
# \end{pmatrix}\begin{pmatrix}
#     0 & -i \\
#     i & 0
# \end{pmatrix} = \begin{pmatrix}
#     1 & 0 \\
#     0 & 1
# \end{pmatrix} = \mathbb{1}\\
# Z^2 = \begin{pmatrix}
#     1 & 0 \\
#     0 & -1
# \end{pmatrix}\begin{pmatrix}
#     1 & 0 \\
#     0 & -1
# \end{pmatrix} = \begin{pmatrix}
#     1 & 0 \\
#     0 & 1
# \end{pmatrix} = \mathbb{1}
# $$
# </details>
#
# c) Show that the Pauli matrices have the following cyclical structure under multiplication.
#
# $$ XY = i Z \qquad YZ = i X \qquad ZX = i Y
# $$
#
# <details>
#     <summary><u><font size = '2'>Answer to c)</font></u></summary>
# We will just check the second of these, as the rest carry through with the exact same method.
# $$ YZ = \begin{pmatrix}
#     0 & -i \\
#     i & 0
# \end{pmatrix}\begin{pmatrix}
#     1 & 0 \\
#     0 & -1
# \end{pmatrix} = \begin{pmatrix}
#     0 & i\\
#     i & 0
# \end{pmatrix} = i\begin{pmatrix}
#     0 & 1 \\
#     1 & 0
# \end{pmatrix} = i X
# $$
# </details>
#
# <!-- ::: -->

# %% [markdown]
# Notice that these properties fully specify the rules for how to multiply the Pauli matrices. In many ways, the algebraic properties above more aptly characterize the Pauli matrices, and in fact, more abstract treatments often use the above rules to *define* the Pauli matrices.
#
# One nice aspect of the above algebraic description of the Paulis is that it treats $X$, $Y$, and $Z$ on more equal footing, as you'll explore in this problem.
#
# <!-- ::: q-block.exercise -->
#
# ### 2.
#
# Convince yourself that the Pauli algebra of the previous exercise is invariant under cyclic permutation of $X, Y, Z$. For example, under the replacement
#
# $$ X \to Y \qquad Y \to Z \qquad Z \to X
# $$
# the algebraic properties remain the same.
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Since all Paulis anticommute with all other Paulis, rearranging the Paulis doesn't change this property. Also, all the Paulis square to the identity, so shuffling them around doesn't change this property either.
#
# The final relationship is inherently cyclic, so a cyclic permutation will leave the set of equations unchanged. Doing the replacement $X \to Y, Y \to Z,$ and $Z \to X$ will turn the first equation into the seocond, the second into the third, and third into the first. Therefore, the set of equations remains unchanged.
#
# Thus, altogether, the algebraic properties do not change under such a transformation. Feel free to test some out with explicit computation if you are still unsure.
# </details>
# <!-- ::: -->

# %% [markdown]
# One lesson here is, while $Z$ may look "special" compared to $X$ and $Y$ for being diagonal, we see that all three matrices are more or less on equal footing, at least in terms of their mathematical behavior.
#
# Let's put our new tools to work. We would like to know what linear combinations of Pauli matrices are unitary. For simplicity (and as an interesting subcase) we will consier *real* combinations first. That is, consider
#
# $$ a X + b Y + c Z
# $$
# for $a, b, c \in \mathbb{R}$.
#
# <!-- ::: q-block.exercise -->
#
# ### 3.
#
# a) Argue that $M = a X + b Y + c Z$ is *Hermitian* (meaning it equals its own conjugate transpose) when $a, b, c$ are real.
#
# <details>
#     <summary><u><font size = '2'>Answer for a)</font></u></summary>
# To compute the conjugate transpose, we could first compute the transpose of $M$, then the complex conjugate. Let's focus on the transpose. One nice property of the transpose is that it is linear. Given a linear combination of matrices $\alpha A + \beta B$, with $\alpha,\beta$ complex, we have
#
#     $$ (\alpha A + \beta B)^T = \alpha A^T +\beta B^T.
#     $$
# Similarly, complex conjugation is *conjugate* linear. Given the same linear combination,
#     $$\overline{(\alpha A + \beta B)} = \overline{\alpha} \overline{A} + \overline{\beta} \overline{B}.
#     $$
# where $\overbar{\alpha}$ denotes the complex conjugate of $\alpha$. Putting these two facts together, we have that the conjugate transpose is conjugate linear. Applied to our present case,
#
# \begin{aligned}
#     (a X + b Y + c Z)^\dagger &= \overbar{a} X^\dagger + \overbar{b} Y^\dagger + \overbar{c} Z^\dagger \\
#     &= \overbar{a} X + \overbar{b} Y + \overbar{c} Z.
# \end{aligned}
# Now we use the fact that $a$, $b$, and $c$ are real, so that $\overbar{a} = a$ and so on. This implies $M^\dagger = M$.
#
# The moral is, a linear combination of Hermitian matrices, with real coefficients, is also Hermitian.
# </details>
#
# b) Next, compute $M^\dagger M$ using only the *algebraic properties* of the Pauli matrices above (do not use matrix multiplication). Comment on the result.
# <details>
#     <summary><u><font size = '2'>Answer for b)</font></u></summary>
# In the last problem, we showed that $M^\dagger = M$, so we really need to compute $M^2$. We have
# \begin{aligned}
#     M^2 &= (aX + b Y + c Z) (a X + b Y + c Z) \\
#     &= a^2 X^2 + b^2 Y^2 + c^2 Z^2 + ab (XY + YX) + bc (YZ + ZY) + ca (ZX + XZ).
# \end{aligned}
# Here, we expanded out the product and grouped terms according to like coefficients. This grouping is helpful for organization, but certainly not necessary.
#
# We observe two things. The terms with a Pauli squared, like $Y^2$, are proportional to the identity $\mathbb{1}$ per the rules of the Paulis. Moreover, the Paulis anticommute, so terms like $ZX + XZ$ are identically zero. This means
# $$ M^2 = (a^2 + b^2 + c^2) \mathbb{1}.
# $$
# This is a striking result. Regardless of our choice of real $a, b$, or $c$, the result is proportional to the identity.
# </details>
#
# c) Finally, answer the question: under what conditions is $M$ unitary?
# <details>
#     <summary><u><font size = '2'>Answer for c)</font></u></summary>
# In the previous part, we found that $M^2 = (a^2 + b^2 + c^2) I$. For $M$ to be unitary, since $M^\dagger = M$, we must have $M^2 = I$. This occurs exactly when
# $$ a^2 + b^2 + c^2 = 1.
# $$
# In words, $M$ is unitary when $(a, b, c)$ is a unit vector.
# </details>
#
# <!-- ::: -->
#
# There is something deeper going on here. We can actually think of $a X + b Y + c Z$, as a vector in three-dimensional space, with components $a,b,c$ along the $X$, $Y$, and $Z$ axes. Unitary operations are vectors on the sphere of radius 1. Taking the square of this matrix is like computing the Euclidean norm of the vector. This interpretation also "explains" why $X$, $Y$, and $Z$ are on equal footing. They are simply three perpendicular directions in space, and no direction is particularly special.
#
# Excellent job!

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 4. Reflection questions and challenges for later
#
# - Do you think these results hold up when we allow the coefficients $a, b, c$ to be complex? Is there something we can say about linear combinations in this case?
#
# - Sometimes, the identity $\mathbb{1}$ is treated as a sort of "fourth Pauli". What linear combinations of $\{\mathbb{1}, X, Y, Z\}$ product unitary operations?
#
# <!-- ::: -->

# %% [markdown]
# <font size = '6'> Reflection operators</font>
#
# A Hermitian, or self-adjoint, matrix $H$ is defined as a matrix equal to its conjugate transpose.
# $H^\dagger = (H^T)^* = H$
#
# <!-- ::: q-block.exercise -->
#
# ### 1.
# Argue that such a matrix is necessarily square.
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Suppose $H$ is $n\times m$ for some positive integers $n, m$. To obtain $H^\dagger$, we first take the transpose, which turns rows into columns and vice versa. This new matrix $H^T$ has dimension $m \times n$ (why?). Next, we take the complex conjugate of each entry, which does not change the dimension. Hence $H^\dagger$ is also $m \times n$.
#
# But by assumption, $H^\dagger = H$, so both matrices must have the same dimensions. Comparing $n\times m$ and $m \times n$, we see that $n$ must equal $m$. Hence, $H$ is square.
#
# In brief, a self-adjoint matrix must have the same number of rows and columns so that the transposition operation doesn't change the dimension.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 2.
# Argue further that its diagonal elements are real.
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# We can write the condition for being self-adjoint as $H_{ij} = H_{ji}^*$, where $H_{ij}$ is the $ij$th entry of the matrix. For diagonal entries, $i = j$. Hence, for these entries $H_{ii} = H_{ii}^*$. We see that the diagonal entries must equal their own complex conjugate. Only real numbers satisfy this property. See if you can convince yourself of this.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### 3.
# Show that the Hadamard operation is both Hermitian and unitary. Show that the Pauli matrices square to the identity: $\sigma_i^2=I$ for each $i=x,y,z$.
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Recall that the Hadamard operation is given in matrix form by
# $$H = \frac{1}{\sqrt{2}} \begin{pmatrix}
# 1 & 1 \\
# 1 & -1
# \end{pmatrix}.
# $$
# This matrix is clearly real, and symmetric, so it must also be Hermitian. Hence, $H^\dagger = H$. We've already seen that the Hadamard is unitary; if you're not convinced try to calculate it yourself!
#
# As for the Pauli matrices squaring to $I$, we will demonstrate for only the pauli-Y matrix. We have
# $$\begin{pmatrix}
#     0 & -i \\
#     i & 0
# \end{pmatrix} \begin{pmatrix}
#     0 & -i \\
#     i & 0
# \end{pmatrix} = \begin{pmatrix}
#     0-i^2 & 0 \\
#     0 & -i^2+0
# \end{pmatrix} = I.
# $$
# The calculations for $\sigma_x$ and $\sigma_z$ are only simpler.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# You might notice the Hadamard and pauli operations share similar properties. To explore this further, consider the following three statements about a matrix $M$.
#
# (a) $M$ is a self-adjoint matrix.
#
# (b) $M$ is a unitary matrix.
#
# (c) $M$ is self-inverse: $M^2=I$.
#
# <!-- ::: q-block.exercise -->
#
# ### 4.
# Prove that, if any two of these statements holds, so does the third.
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# First of all, if any one of these conditions holds, then $M$ is square (why?). Therefore, we can restrict our attention to square matrices for the rest of the arguments below.
#
# Suppose (a) and (b) hold for a matrix $M$. Since $M$ is Hermitian, $M^2 = M M^\dagger$. Since $M$ is unitary, $M M^\dagger = I$. Thus, property (c) holds.
#
# Now suppose (b) and (c) hold for $M$. Property (c) says $M = M^{-1}$. Property (b) says $M^{-1} = M^\dagger$. Combining these together through transitivity we see that $M = M^\dagger$. Hence, condition (a) holds.
#
# Finally, suppose (c) and (a) hold. We have $M = M^\dagger$ and $M^2 = I$. Hence, $M^2 = M M^\dagger = I$. Thus, $M$ is unitary.
# </details>
#
# <!-- ::: -->

# %% [markdown]
# A matrix $R$ satisfying the properties above (or any two of them) is said to be a *reflection*. To see why, suppose $R$ has eigenvector $v$ with eigenvalue $\lambda$, i.e. $Rv = \lambda v$ where $\lambda$ is a number and $v \neq 0$.
#
# <!-- ::: q-block.exercise -->
#
# ### 5.
# Show that $\lambda=1$ or $\lambda=-1$.
#
# <details>
#     <summary><u><font size = '2'>Hint</font></u></summary>
# Try applying $R$ to both sides of the eigenvector equation. Can you make use of any properties?
# </details>
#
# <details>
#     <summary><u><font size = '2'>Answer with explanation</font></u></summary>
# Suppose $R v = \lambda v$, where $v$ is a vector and $\lambda$ is a number. Let's apply $R$ again, because in the spirit of "reflections" we expect to get back to where we started. We have
# $$
# \begin{aligned}
#     R(Rv) &= R(\lambda v) \\
#     R^2 v &= \lambda R v \\
#     v &= \lambda^2 v.
# \end{aligned}
# $$
# Here we used the fact that $R$ is linear, $R^2 = I$ and $v$ is an eigenvector of $R$. Since $v = \lambda^2 v$ and $v \neq 0$, we must have $\lambda^2 = 1$. Hence, $\lambda = 1$ or $-1$.
# </details>
#
# <!-- ::: -->
#
# Thus, we see that the eigenvector $v$ is either “perpendicular to the mirror surface” ($\lambda = -1$) and therefore reflected, or “parallel” $(\lambda = 1)$ and then left unchanged. Reflection operations feature prominently in quantum algorithms, such as those for unstructured search, where the special element to be searched for is reflected while the others are untouched.

# %% [markdown]
# ## Where should I go next?

# %% [markdown]
# Well done on making it this far! If you feel comfortable with the exercises of the previous sections, you have acquired facility with a simplified framework for the study of quantum information theory. This framework will continue to expand as you proceed through the lessons.
#
# The tools learned here will be indispensable as you continue on to study [Multiple Systems](https://learn.qiskit.org/course/basics/multiple-systems). Combining small systems to create large state spaces is crucial to nearly every aspect of quantum information, and it is a natural next step in your path to understanding the basics of quantum information.
