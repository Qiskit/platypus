# %% [markdown]
# # UTokyo 01 - Introduction to Near-Term Quantum Computing

# %% [markdown]
# ## Overview
#
# **The University of Tokyo** <br>
# **Introduction to Near-Term Quantum Computing**<br>
# **量子計算論**
#
# <br>
#
# **Unit 1: Welcome to Introduction to Near-Term Quantum Computing!**
#
#
# This set of questions is based on the following contents:
#
# - [VIDEO: Understanding Quantum Information and Computation | Lesson 1 (John Watrous)](https://youtu.be/3-c4xJa7Flk)
# - [TEXTBOOK: Single systems of Basics of quantum information](https://learn.qiskit.org/course/basics/single-systems)
#
# Please refer to the [online syllabus](https://learn.qiskit.org/syllabus/RBD-9TW) for additional information.

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quick quiz
#
# <!-- ::: q-quiz(goal="utokyo_01_0") -->
#
# <!-- ::: .question -->
#
# Ready for your quiz?
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# 1. Yes -- Let's go!
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# 2. Not yet, I need to watch the video and read the textbook again.
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-1

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-1
#
# <!-- ::: q-quiz(goal="utokyo_01_1") -->
#
# <!-- ::: .question -->
#
# Which of the following is a probability vector?
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} \sqrt{2}\\\\ 1 - \sqrt{2} \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 0.4 \\\\ 0.4 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# $\begin{pmatrix} 1 \\\\ 0 \\\\ 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-2

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-2
#
# <!-- ::: q-quiz(goal="utokyo_01_2") -->
#
# <!-- ::: .question -->
#
# Which of the following is a quantum state vector?
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} \sqrt{2}\\\\ 1 - \sqrt{2} \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# $\begin{pmatrix} -\frac{1+2i}{3} \\\\ -\frac{2}{3} \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 1 \\\\ 0 \\\\ 1 \end{pmatrix}$
#
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-3

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-3
#
# <!-- ::: q-quiz(goal="utokyo_01_3") -->
#
# <!-- ::: .question -->
#
# Which of the following is a deterministic operator?
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 1 & 0 \\\\ 1 & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 0 & \frac{1}{2} \\\\ \frac{-i}{2} & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 1 & 0 \\\\ 0 & i \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# $\begin{pmatrix} 0 & 0 \\\\ 1 & 1 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-4

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-4
#
# <!-- ::: q-quiz(goal="utokyo_01_4") -->
#
# <!-- ::: .question -->
#
# Which of the following is a probabilistic operator?
#
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 1 & 0 \\\\ 1 & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# $\begin{pmatrix} \frac{1}{2} & 0 \\\\ \frac{1}{2} & 1 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 1 & 0 \\\\ 0 & i \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 0 & \frac{1}{2} \\\\ \frac{-i}{2} & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-5

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-5
#
# <!-- ::: q-quiz(goal="utokyo_01_5") -->
#
# <!-- ::: .question -->
#
# Which of the following is unitary?
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 1 & 0 \\\\ 1 & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\begin{pmatrix} 0 & \frac{1}{2} \\\\ \frac{-i}{2} & 0 \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# $\begin{pmatrix} 1 & 0 \\\\ 0 & i \end{pmatrix}$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-6

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-6
#
# <!-- ::: q-quiz(goal="utokyo_01_6") -->
#
# <!-- ::: .question -->
#
# The probabilities of result in 0 and 1 by measuring the plus state or the minus state is same as far as standard basis measurements.
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Yes
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# No
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-7

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-7
#
# <!-- ::: q-quiz(goal="utokyo_01_7") -->
#
# <!-- ::: .question -->
#
# Which operation is equal to $ HZH $ ?
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# $X$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $Y$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $Z$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $H$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-8

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-8
#
# <!-- ::: q-quiz(goal="utokyo_01_8") -->
#
# <!-- ::: .question -->
#
# Which operation is equal to $ HXH $ ?
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $X$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $Y$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# $Z$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $H$
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-9

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-9
#
# <!-- ::: q-quiz(goal="utokyo_01_9") -->
#
# <!-- ::: .question -->
#
# What is $ S|-\rangle$ ?
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\frac{1}{\sqrt{2}}|0\rangle + \frac{1}{\sqrt{2}}|1\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\frac{1}{\sqrt{2}}|0\rangle -\frac{1}{\sqrt{2}}|1\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# $\frac{1}{\sqrt{2}}|0\rangle +\frac{i}{\sqrt{2}}|1\rangle$
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# $\frac{1}{\sqrt{2}}|0\rangle -\frac{i}{\sqrt{2}}|1\rangle$
#
#
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# ## Quiz 1-10

# %% [markdown]
# <!-- ::: q-block.exercise -->
#
# ### Quiz 1-10
#
# <!-- ::: q-quiz(goal="utokyo_01_10") -->
#
# <!-- ::: .question -->
#
# Permutation matrices are the only matrices that can represent both classical and quantum operations.
#
# <!-- ::: -->
#
# <!-- ::: .option(correct) -->
#
# Yes
#
# <!-- ::: -->
#
# <!-- ::: .option -->
#
# No
#
# <!-- ::: -->
#
# <!-- ::: -->
#
# <!-- ::: -->

# %% [markdown]
# This is the end of this week's quiz!
#
# **Please take a screenshot and submit it to ITC-LMS.**
